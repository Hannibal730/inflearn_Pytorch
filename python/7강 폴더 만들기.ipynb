# %% [markdown]
# # 7강. 폴더 만들기
#
# 코드가 진행 중에 데이터를 특정 폴더에 저장하고 싶다면 미리 폴더를 생성 해야만 한다. 이 때 생성할 결과물이 많고 폴더를 여러 개로 나누어 저장하는 경우에는 번거로운 일이 된다. 이를 해소하고자 코드 시작 시 자동으로 폴더의 유무를 확인하고 생성한다.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/My Drive/deeplearningbrov2/python
# Out:
# /content/gdrive/My Drive/deeplearningbrov2/python

# %%
import numpy as np

# %%
data = np.ones(2)
np.save('./data/class/ones.npy', data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c49845c167e7> in <module>
#       1 data = np.ones(2)
# ----> 2 np.save('./data/class/ones.npy', data)
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in save(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/lib/npyio.py in save(file, arr, allow_pickle, fix_imports)
#     513         if not file.endswith('.npy'):
#     514             file = file + '.npy'
# --> 515         file_ctx = open(file, "wb")
#     516
#     517     with file_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/class/ones.npy'

# %%
import os

def directory_create(folder_name):
    try:
        os.makedirs(folder_name)
        print("Directory ", folder_name,  ": Created ")
    except FileExistsError:
        print("Directory ", folder_name,  ": Already exists")

# %%
directory_create('data/class')
# directory_create('data')
# directory_create('data/class/lion')
# Out:
# Directory  data/class : Created

# %%
np.save('./data/class/ones.npy', data)

# %%
directory_create('data/class')
# Out:
# Directory  data/class : Already exists
